# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/Vishal/Desktop/Zomatodataset/zomato.csv',encoding='latin')

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df.head(3)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
for feature in df.columns:
    if df[feature].isnull().sum()>0:
        print(feature)
# Out:
# Cuisines

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar='viridis')
plt.show()

# %%
df1 = pd.read_excel('C:/Users/Vishal/Desktop/Zomatodataset/country-Code.xlsx')

# %% [markdown]
# df1

# %%
final_df = df.merge(df1,on='Country Code',how = 'left')

# %%
final_df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
country_name = final_df.Country.value_counts().index

# %%
country_name
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'UAE',
#        'South Africa', 'New Zealand', 'Turkey', 'Australia', 'Phillipines',
#        'Indonesia', 'Singapore', 'Qatar', 'Sri Lanka', 'Canada'],
#       dtype='object', name='Country')

# %%
country_value = final_df.Country.value_counts().values

# %%
country_value
# Out:
# array([8652,  434,   80,   60,   60,   60,   40,   34,   24,   22,   21,
#          20,   20,   20,    4], dtype=int64)

# %%
plt.pie(country_value[:3],labels=country_name[:3],autopct='%1.2f%%')
plt.show()

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
rating =final_df.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating_Count'})

# %%
rating
# Out:
#     Aggregate rating Rating color Rating text  Rating_Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# # observation
# 1. Dark Green , Excellent, 4.9-4.5
# 2. Green , Very Good , 4.0 -4.4
# 3. Yellow, Green, 3.5 - 3.9
# 4. Orange , Average , 2.5 - 3.4
# 5. Red, Poor, 0.1-2.4
# 6. White. Not rated, 0

# %%
rating.columns
# Out:
# Index(['Aggregate rating', 'Rating color', 'Rating text', 'Rating_Count'], dtype='object')

# %%
plt.figure(figsize=(10,4))
sns.barplot(x='Aggregate rating', y='Rating_Count',data=rating,palette='viridis')
plt.show()
# Out:
# C:\Users\Vishal\AppData\Local\Temp\ipykernel_19316\3653319356.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Aggregate rating', y='Rating_Count',data=rating,palette='viridis')

# %%
rating.columns
# Out:
# Index(['Aggregate rating', 'Rating color', 'Rating text', 'Rating_Count'], dtype='object')

# %%
plt.figure(figsize=(10,4))
colors = ['grey','red','orange','yellow','green','black']
sns.countplot(x='Rating color',data = rating,palette=colors)
plt.show()
# Out:
# C:\Users\Vishal\AppData\Local\Temp\ipykernel_19316\1611531048.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Rating color',data = rating,palette=colors)

# %%
final_df[final_df['Rating color']=='White'].groupby(['Country']).size().reset_index().rename(columns={0:'Rating_Count'})
# Out:
#           Country  Rating_Count
# 0          Brazil             5
# 1           India          2139
# 2  United Kingdom             1
# 3   United States             3

# %%
final_df.groupby(['Aggregate rating','Country']).size().reset_index().head()
# Out:
#    Aggregate rating         Country     0
# 0               0.0          Brazil     5
# 1               0.0           India  2139
# 2               0.0  United Kingdom     1
# 3               0.0   United States     3
# 4               1.8           India     1

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
# In what different currencies are we doing work ?
final_df[[ 'Country','Currency']].groupby(['Country','Currency']).size().reset_index().head()
# Out:
#      Country                Currency     0
# 0  Australia               Dollar($)    24
# 1     Brazil      Brazilian Real(R$)    60
# 2     Canada               Dollar($)     4
# 3      India      Indian Rupees(Rs.)  8652
# 4  Indonesia  Indonesian Rupiah(IDR)    21

# %%
final_df['Has Online delivery'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# How many countries have online delivery service.
final_df[final_df[ 'Has Online delivery']=='Yes'].Country.value_counts()
# Out:
# Country
# India    2423
# UAE        28
# Name: count, dtype: int64

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
city_name =final_df.City.value_counts().index
city_val =final_df.City.value_counts().values

# %%
city_name, city_val
# Out:
# (Index(['New Delhi', 'Gurgaon', 'Noida', 'Faridabad', 'Ghaziabad',
#         'Bhubaneshwar', 'Amritsar', 'Ahmedabad', 'Lucknow', 'Guwahati',
#         ...
#         'Ojo Caliente', 'Montville', 'Monroe', 'Miller', 'Middleton Beach',
#         'Panchkula', 'Mc Millan', 'Mayfield', 'Macedon', 'Vineland Station'],
#        dtype='object', name='City', length=141),
#  array([5473, 1118, 1080,  251,   25,   21,   21,   21,   21,   21,   20,
#           20,   20,   20,   20,   20,   20,   20,   20,   20,   20,   20,
#           20,   20,   20,   20,   20,   20,   20,   20,   20,   20,   20,
#           20,   20,   20,   20,   20,   20,   20,   20,   20,   20,   20,
#           20,   20,   20,   20,   20,   20,   20,   20,   20,   20,   20,
#           20,   20,   20,   20,   20,   20,   20,   20,   20,   20,   20,
#           20,   20,   20,   20,   20,   20,   20,   20,   20,   20,   20,
#           18,   18,   16,   14,   11,    6,    4,    4,    3,    3,    2,
# ...

# %%
plt.pie(x=city_val[:3],labels=city_name[:3],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2525a9baf00>,
# ...
#  [Text(-0.6836225695617262, 0.8617773392157762, 'New Delhi'),
#   Text(0.24897482286810813, -1.0714530029720364, 'Gurgaon'),
#   Text(0.9941442744692855, -0.47082604169686504, 'Noida')],
#  [Text(-0.37288503794275973, 0.47006036684496877, '71.35%'),
#   Text(0.13580444883714987, -0.5844289107120197, '14.57%'),
#   Text(0.542260513346883, -0.25681420456192633, '14.08%')])

# %%
plt.pie(x=city_val[:10],labels=city_name[:10],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2525aa15940>,
# ...
#  [Text(-0.5885541119444019, 0.9293029954290133, 'New Delhi'),
#   Text(-0.006008322137253758, -1.099983590816288, 'Gurgaon'),
#   Text(0.8279428936915272, -0.7242310161721195, 'Noida'),
#   Text(1.0782100088727444, -0.21786045250718752, 'Faridabad'),
#   Text(1.0953795414972105, -0.10071573893568578, 'Ghaziabad'),
#   Text(1.097010627021975, -0.08104124999562284, 'Bhubaneshwar'),
#   Text(1.0981912920377443, -0.06305462784340321, 'Amritsar'),
#   Text(1.0990770676906627, -0.04505107408813379, 'Ahmedabad'),
#   Text(1.0996677161298025, -0.027035423093857848, 'Lucknow'),
#   Text(1.0999630787526116, -0.00901251247300567, 'Guwahati')],
#  [Text(-0.3210295156060373, 0.50689254296128, '67.97%'),
#   Text(-0.003277266620320231, -0.5999910495361571, '13.88%'),
#   Text(0.4516052147408329, -0.3950350997302469, '13.41%'),
#   Text(0.5881145502942242, -0.11883297409482954, '3.12%'),
#   Text(0.5974797499075692, -0.054935857601283146, '0.31%'),
# ...

# %%
# find top 10 Cussines

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df['Cuisines'].isnull().sum()
# Out:
# 9

# %%
city_name =final_df.Cuisines.value_counts().index
city_val =final_df.Cuisines.value_counts().values

# %%
city_name, city_val
# Out:
# (Index(['North Indian', 'North Indian, Chinese', 'Chinese', 'Fast Food',
#         'North Indian, Mughlai', 'Cafe', 'Bakery',
#         'North Indian, Mughlai, Chinese', 'Bakery, Desserts', 'Street Food',
#         ...
#         'Cafe, Pizza, Burger',
#         'Healthy Food, Continental, Juices, Beverages, Italian, Salad, Lebanese',
#         'Goan, American, Portuguese', 'South Indian, Desserts, Beverages',
#         'Healthy Food, North Indian, Italian, Salad', 'Bengali, Fast Food',
#         'North Indian, Rajasthani, Asian',
#         'Chinese, Thai, Malaysian, Indonesian',
#         'Bakery, Desserts, North Indian, Bengali, South Indian',
#         'Italian, World Cuisine'],
#        dtype='object', name='Cuisines', length=1825),
#  array([936, 511, 354, ...,   1,   1,   1], dtype=int64))

# %%
plt.pie(x=city_val[:10],labels=city_name[:10],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2525a7cd790>,
# ...
#  [Text(0.7383739846958008, 0.8153550507137645, 'North Indian'),
#   Text(-0.5794679314239953, 0.9349956772366362, 'North Indian, Chinese'),
#   Text(-1.067309479615702, 0.26617752482593154, 'Chinese'),
#   Text(-1.0185984499802057, -0.4152796620326146, 'Fast Food'),
#   Text(-0.5935788454809928, -0.9261015895664211, 'North Indian, Mughlai'),
#   Text(-0.005887079599915552, -1.0999842463843672, 'Cafe'),
#   Text(0.4842062514572988, -0.9876964645323336, 'Bakery'),
#   Text(0.808736477166136, -0.7456174022251013, 'North Indian, Mughlai, Chinese'),
#   Text(1.0055375294202338, -0.44597564611473206, 'Bakery, Desserts'),
#   Text(1.090298995560443, -0.14576728123927227, 'Street Food')],
#  [Text(0.4027494461977095, 0.4447391185711442, '26.58%'),
#   Text(-0.316073417140361, 0.5099976421290743, '14.51%'),
#   Text(-0.5821688070631101, 0.14518774081414446, '10.05%'),
#   Text(-0.5555991545346576, -0.22651617929051704, '10.05%'),
# ...

# %% [markdown]
# # Project End
